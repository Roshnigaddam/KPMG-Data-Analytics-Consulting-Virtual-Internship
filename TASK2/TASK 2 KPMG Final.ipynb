# %%
#import modules
import pandas as pd # for dataframes
import matplotlib.pyplot as plt # for plotting graphs
import seaborn as sns # for plotting graphs
import datetime as dt
import numpy as np

# %% [markdown]
# # LABELLING TRAINING DATA USING RFM MODEL

# %% [markdown]
# Recency, Frequency and Monetary (Profit Margin) are the calculated fields that were created in the Tableau Prep Builder.
# - Recency - Is the number of days from the last transaction made by the customer.
# - Frequency - Number of Transactions the customer has made during the period of consideration.
# - Monetary- Profit amount from all the transactions made by the customer.

# %%
data = pd.read_excel('C:\\Users\\Roshni Gaddam\\Downloads\\kpmg\\Customer rfm.xlsx')

# %%
data.dtypes
# Out:
# customer_id                              int64
# address                                 object
# postcode                                 int64
# state                                   object
# country                                 object
# property_valuation                       int64
# first_name                              object
# last_name                               object
# gender                                  object
# past_3_years_bike_related_purchases      int64
# job_title                               object
# job_industry_category                   object
# wealth_segment                          object
# deceased_indicator                      object
# owns_car                                object
# tenure                                   int64
# count transaction_id                     int64
# list_price                             float64
# standard_cost                          float64
# Age                                      int64
# Recency                                  int64
# Frequency                                int64
# Margin(Monetary)                       float64
# dtype: object

# %%
data.head()
# Out:
#    customer_id               address  postcode state    country  \
# 0         2322       496 Summit Road      2120   NSW  Australia
# 1         2278       31953 Dixon Way      2580   NSW  Australia
# 2         1052   06 Declaration Hill      3184   VIC  Australia
# 3         2066         9 Logan Court      2570   NSW  Australia
# 4         2838  50469 Shelley Avenue      4350   QLD  Australia
#
#    property_valuation first_name    last_name  gender  \
# 0                  10    Hazlett  Rosenschein    Male
# 1                   4      Gerri       Heliet    Male
# 2                  11       Dela    Flannigan  Female
# 3                   9      Skipp     McLarens    Male
# 4                   8      Lydie   Scholfield  Female
#
#    past_3_years_bike_related_purchases  ... deceased_indicator owns_car  \
# 0                                   72  ...                  N      Yes
# 1                                   11  ...                  N      Yes
# 2                                   31  ...                  N       No
# 3                                   91  ...                  N      Yes
# 4                                   14  ...                  N       No
#
#   tenure count transaction_id list_price  standard_cost  Age  Recency  \
# 0      2                    4    4035.51        1450.36   28       67
# 1      8                    4    1635.24        1355.46   42       34
# 2      3                    6    8478.41        5218.09   34        0
# 3     12                    5    6115.09        3855.80   50       90
# 4     21                    3    2838.62        1284.28   43       15
#
#    Frequency  Margin(Monetary)
# 0          4           2585.15
# 1          4            279.78
# 2          6           3260.32
# 3          5           2259.29
# 4          3           1554.34
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Dividing the data into RFM segments

# %% [markdown]
# Dividing the data into quartiles using the qcut method.
# Scores are given from 1-4 ranging from Best to Worst respectively.
#
#
# - Most Recent Customer will get a score of 1.
# - Most Frequent customer will get a score of 1.
# - The customer who made purchases worth more monetary terms gets a score of 1.
#
# - Below are the quartiles for all the three columns. Have a look at the r_quartile, f_quartile and m_quartile to understand how the scores are being assigned with respect to the quartile values.

# %%
quartiles = data[['Recency','Frequency','Margin(Monetary)']].quantile(q=[0.25,0.50,0.75])
print(quartiles)
# Out:
#       Recency  Frequency  Margin(Monetary)
# 0.25     18.0        4.0          1766.355
# 0.50     45.0        5.0          2785.040
# 0.75     88.0        7.0          4063.625

# %%
data['r_quartile'] = pd.qcut(data['Recency'], 4, ['1','2','3','4'])
data['f_quartile'] = pd.qcut(data['Frequency'], 4, ['4','3','2','1'] )
data['m_quartile'] = pd.qcut(data['Margin(Monetary)'], 4, ['4','3','2','1'])

# %%
data.head()
# Out:
#    customer_id               address  postcode state    country  \
# 0         2322       496 Summit Road      2120   NSW  Australia
# 1         2278       31953 Dixon Way      2580   NSW  Australia
# 2         1052   06 Declaration Hill      3184   VIC  Australia
# 3         2066         9 Logan Court      2570   NSW  Australia
# 4         2838  50469 Shelley Avenue      4350   QLD  Australia
#
#    property_valuation first_name    last_name  gender  \
# 0                  10    Hazlett  Rosenschein    Male
# 1                   4      Gerri       Heliet    Male
# 2                  11       Dela    Flannigan  Female
# 3                   9      Skipp     McLarens    Male
# 4                   8      Lydie   Scholfield  Female
#
#    past_3_years_bike_related_purchases  ... count transaction_id list_price  \
# 0                                   72  ...                    4    4035.51
# 1                                   11  ...                    4    1635.24
# 2                                   31  ...                    6    8478.41
# 3                                   91  ...                    5    6115.09
# 4                                   14  ...                    3    2838.62
#
#   standard_cost Age Recency  Frequency  Margin(Monetary)  r_quartile  \
# 0       1450.36  28      67          4           2585.15           3
# 1       1355.46  42      34          4            279.78           2
# 2       5218.09  34       0          6           3260.32           1
# 3       3855.80  50      90          5           2259.29           4
# 4       1284.28  43      15          3           1554.34           1
#
#    f_quartile  m_quartile
# 0           4           3
# 1           4           4
# 2           2           2
# 3           3           3
# 4           4           4
#
# [5 rows x 26 columns]

# %% [markdown]
# Creating a combined score.

# %%
data['RFM_Score'] = data.r_quartile.astype(str)+ data.f_quartile.astype(str) + data.m_quartile.astype(str)
data.head()
# Out:
#    customer_id               address  postcode state    country  \
# 0         2322       496 Summit Road      2120   NSW  Australia
# 1         2278       31953 Dixon Way      2580   NSW  Australia
# 2         1052   06 Declaration Hill      3184   VIC  Australia
# 3         2066         9 Logan Court      2570   NSW  Australia
# 4         2838  50469 Shelley Avenue      4350   QLD  Australia
#
#    property_valuation first_name    last_name  gender  \
# 0                  10    Hazlett  Rosenschein    Male
# 1                   4      Gerri       Heliet    Male
# 2                  11       Dela    Flannigan  Female
# 3                   9      Skipp     McLarens    Male
# 4                   8      Lydie   Scholfield  Female
#
#    past_3_years_bike_related_purchases  ... list_price standard_cost Age  \
# 0                                   72  ...    4035.51       1450.36  28
# 1                                   11  ...    1635.24       1355.46  42
# 2                                   31  ...    8478.41       5218.09  34
# 3                                   91  ...    6115.09       3855.80  50
# 4                                   14  ...    2838.62       1284.28  43
#
#   Recency Frequency  Margin(Monetary)  r_quartile  f_quartile  m_quartile  \
# 0      67         4           2585.15           3           4           3
# 1      34         4            279.78           2           4           4
# 2       0         6           3260.32           1           2           2
# 3      90         5           2259.29           4           3           3
# 4      15         3           1554.34           1           4           4
#
#    RFM_Score
# 0        343
# 1        244
# 2        122
# 3        433
# 4        144
#
# [5 rows x 27 columns]

# %% [markdown]
# The customers are labelled as "Best" and "Others" if their RFM scores are in the following range.
# "R_label" will act as the target variable.

# %%
def RFMlabel(x):
    if (x['RFM_Score'] in ['111','112','121','211','122','212','221','222','311','312','321','322']): 
        return "Best"
    
    else: 
        return "Others"

# %%
rfmSeg = data
rfmSeg['R_label'] = rfmSeg.apply(RFMlabel,axis=1)
rfmSeg
# Out:
#       customer_id                  address  postcode state    country  \
# 0            2322          496 Summit Road      2120   NSW  Australia
# 1            2278          31953 Dixon Way      2580   NSW  Australia
# 2            1052      06 Declaration Hill      3184   VIC  Australia
# 3            2066            9 Logan Court      2570   NSW  Australia
# 4            2838     50469 Shelley Avenue      4350   QLD  Australia
# ...           ...                      ...       ...   ...        ...
# 2514         2306       9 Lake View Avenue      3178   VIC  Australia
# 2515         2041       51739 Sundown Hill      2009   NSW  Australia
# 2516          279            34 Kim Center      2036   NSW  Australia
# 2517          343  6860 Green Ridge Avenue      2126   NSW  Australia
# 2518          508         4 Thackeray Pass      2487   NSW  Australia
#
#       property_valuation first_name    last_name  gender  \
# 0                     10    Hazlett  Rosenschein    Male
# 1                      4      Gerri       Heliet    Male
# 2                     11       Dela    Flannigan  Female
# 3                      9      Skipp     McLarens    Male
# 4                      8      Lydie   Scholfield  Female
# ...                  ...        ...          ...     ...
# 2514                   9     Hilary     Tregunna  Female
# 2515                   9       Mort        Heath    Male
# 2516                  11     Tamera      Hinckes  Female
# 2517                  11     Nicole   Johananoff  Female
# 2518                   9    Abagail     Tordiffe  Female
#
#       past_3_years_bike_related_purchases  ... standard_cost Age Recency  \
# 0                                      72  ...       1450.36  28      67
# 1                                      11  ...       1355.46  42      34
# 2                                      31  ...       5218.09  34       0
# 3                                      91  ...       3855.80  50      90
# 4                                      14  ...       1284.28  43      15
# ...                                   ...  ...           ...  ..     ...
# 2514                                   98  ...       2424.86  60       6
# 2515                                   52  ...       3929.78  62      80
# 2516                                    0  ...       1361.24  39      14
# 2517                                   76  ...       5171.00  63     133
# 2518                                   94  ...       2764.19  49     155
#
#      Frequency Margin(Monetary)  r_quartile  f_quartile  m_quartile  \
# 0            4          2585.15           3           4           3
# 1            4           279.78           2           4           4
# 2            6          3260.32           1           2           2
# 3            5          2259.29           4           3           3
# 4            3          1554.34           1           4           4
# ...        ...              ...         ...         ...         ...
# 2514         4          2513.78           1           4           3
# 2515         6          3799.86           3           2           2
# 2516         6          2455.93           1           2           3
# 2517         8          3914.16           4           1           2
# 2518         4          2587.54           4           4           3
#
#       RFM_Score  R_label
# 0           343   Others
# 1           244   Others
# 2           122     Best
# 3           433   Others
# 4           144   Others
# ...         ...      ...
# 2514        143   Others
# 2515        322     Best
# 2516        123   Others
# 2517        412   Others
# 2518        443   Others
#
# [2519 rows x 28 columns]

# %%
rfmSeg.groupby('R_label').count()
# Out:
#          customer_id  address  postcode  state  country  property_valuation  \
# R_label
# Best             808      808       808    808      808                 808
# Others          1711     1711      1711   1711     1711                1711
#
#          first_name  last_name  gender  past_3_years_bike_related_purchases  \
# R_label
# Best            808        785     808                                  808
# Others         1711       1658    1711                                 1711
#
#          ...  list_price  standard_cost   Age  Recency  Frequency  \
# R_label  ...
# Best     ...         808            808   808      808        808
# Others   ...        1711           1711  1711     1711       1711
#
#          Margin(Monetary)  r_quartile  f_quartile  m_quartile  RFM_Score
# R_label
# Best                  808         808         808         808        808
# Others               1711        1711        1711        1711       1711
#
# [2 rows x 27 columns]

# %%
rfmSeg.rename(columns = {'customer_id':'ID'}, inplace = True)

# %%
#rfmSeg.to_excel(r'C:\Users\Roshni Gaddam\Downloads\kpmg\kdata\trainc4.xlsx', index=False)

# %%
df = pd.read_excel('C:\\Users\\Roshni Gaddam\\Downloads\\kpmg\\kdata\\trainc4.xlsx')

# %%
df.head()
# Out:
#      ID               address  postcode state    country  property_valuation  \
# 0  2322       496 Summit Road      2120   NSW  Australia                  10
# 1  2278       31953 Dixon Way      2580   NSW  Australia                   4
# 2  1052   06 Declaration Hill      3184   VIC  Australia                  11
# 3  2066         9 Logan Court      2570   NSW  Australia                   9
# 4  2838  50469 Shelley Avenue      4350   QLD  Australia                   8
#
#   first_name    last_name  gender  past_3_years_bike_related_purchases  ...  \
# 0    Hazlett  Rosenschein    Male                                   72  ...
# 1      Gerri       Heliet    Male                                   11  ...
# 2       Dela    Flannigan  Female                                   31  ...
# 3      Skipp     McLarens    Male                                   91  ...
# 4      Lydie   Scholfield  Female                                   14  ...
#
#   standard_cost Age Recency Frequency Margin(Monetary)  r_quartile  \
# 0       1450.36  28      67         4          2585.15           3
# 1       1355.46  42      34         4           279.78           2
# 2       5218.09  34       0         6          3260.32           1
# 3       3855.80  50      90         5          2259.29           4
# 4       1284.28  43      15         3          1554.34           1
#
#    f_quartile  m_quartile  RFM_Score  R_label
# 0           4           3        343   Others
# 1           4           4        244   Others
# 2           2           2        122     Best
# 3           3           3        433   Others
# 4           4           4        144   Others
#
# [5 rows x 28 columns]

# %% [markdown]
# Data is divided into segments based on 'Age'. 'Age' is being converted into a categorical value.

# %%
df['Age']=pd.cut(df.Age,bins=[15,35,50,90],labels=['Young Adults','Middle Age','Older'])

# %%
df.head()
# Out:
#      ID               address  postcode state    country  property_valuation  \
# 0  2322       496 Summit Road      2120   NSW  Australia                  10
# 1  2278       31953 Dixon Way      2580   NSW  Australia                   4
# 2  1052   06 Declaration Hill      3184   VIC  Australia                  11
# 3  2066         9 Logan Court      2570   NSW  Australia                   9
# 4  2838  50469 Shelley Avenue      4350   QLD  Australia                   8
#
#   first_name    last_name  gender  past_3_years_bike_related_purchases  ...  \
# 0    Hazlett  Rosenschein    Male                                   72  ...
# 1      Gerri       Heliet    Male                                   11  ...
# 2       Dela    Flannigan  Female                                   31  ...
# 3      Skipp     McLarens    Male                                   91  ...
# 4      Lydie   Scholfield  Female                                   14  ...
#
#   standard_cost           Age Recency Frequency Margin(Monetary)  r_quartile  \
# 0       1450.36  Young Adults      67         4          2585.15           3
# 1       1355.46    Middle Age      34         4           279.78           2
# 2       5218.09  Young Adults       0         6          3260.32           1
# 3       3855.80    Middle Age      90         5          2259.29           4
# 4       1284.28    Middle Age      15         3          1554.34           1
#
#    f_quartile  m_quartile  RFM_Score R_label
# 0           4           3        343  Others
# 1           4           4        244  Others
# 2           2           2        122    Best
# 3           3           3        433  Others
# 4           4           4        144  Others
#
# [5 rows x 28 columns]

# %%
df.groupby('R_label').count()
# Out:
#            ID  address  postcode  state  country  property_valuation  \
# R_label
# Best      808      808       808    808      808                 808
# Others   1711     1711      1711   1711     1711                1711
#
#          first_name  last_name  gender  past_3_years_bike_related_purchases  \
# R_label
# Best            808        785     808                                  808
# Others         1711       1658    1711                                 1711
#
#          ...  list_price  standard_cost   Age  Recency  Frequency  \
# R_label  ...
# Best     ...         808            808   808      808        808
# Others   ...        1711           1711  1711     1711       1711
#
#          Margin(Monetary)  r_quartile  f_quartile  m_quartile  RFM_Score
# R_label
# Best                  808         808         808         808        808
# Others               1711        1711        1711        1711       1711
#
# [2 rows x 27 columns]

# %% [markdown]
# ### Undersampling

# %% [markdown]
# The ratio of records with "Best" and "Others" is nearly 1:2.
# Therefore to prevent bias, the dominant class "Others" is undersampled.

# %%
#X = df[['ID','Age', 'gender', 'state', 'property_valuation', 'job_industry_category','past_3_years_bike_related_purchases','wealth_segment','owns_car','tenure']].values

#no_best = len(df[df['R_label'] == "Best"])

#non_fraud_indices = df[df.R_label == "Others"].index

#random_indices = np.random.choice(non_fraud_indices,no_best, replace=False)

#fraud_indices = df[df.R_label == "Best"].index

#under_sample_indices = np.concatenate([fraud_indices,random_indices])

#under_sample = df.loc[under_sample_indices]

#under_sample['R_label']

#no_b = len(under_sample[under_sample['R_label'] == "Best"])

#no_b

#under_sample

#under_sample=under_sample.sample(frac=1)

#under_sample

#under_sample.to_excel(r'C:\Users\Roshni Gaddam\Downloads\kpmg\kdata\UndersampledC4V2.xlsx', index=False)

# %%
under_sample=pd.read_excel('C:\\Users\\Roshni Gaddam\\Downloads\\kpmg\\kdata\\UndersampledC4V2.xlsx')

# %%
no_o = len(under_sample[under_sample['R_label'] == "Others"])

no_o
# Out:
# 808

# %%
no_b = len(under_sample[under_sample['R_label'] == "Best"])

no_b
# Out:
# 808

# %%
X = under_sample[['ID','Age', 'gender', 'state','job_industry_category','past_3_years_bike_related_purchases','wealth_segment','owns_car']].values

# %%
X.shape
# Out:
# (1616, 8)

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# LabelEncoder is used to normalize categorical varaiables.

# %%
from sklearn import preprocessing

le_age = preprocessing.LabelEncoder()
le_age.fit(['Young Adults','Middle Age','Older'])
X[:,1] = le_age.transform(X[:,1]) 

le_gen = preprocessing.LabelEncoder()
le_gen.fit(['Female','Male'])
X[:,2] = le_gen.transform(X[:,2]) 


le_state = preprocessing.LabelEncoder()
le_state.fit([ 'NSW', 'VIC', 'QLD'])
X[:,3] = le_state.transform(X[:,3])

le_job = preprocessing.LabelEncoder()
le_job.fit([ 'Agriculture', 'Entertainment', 'Financial Services','Health','IT','Manufacturing','Property','Retail','Telecommunications'])
X[:,4] = le_job.transform(X[:,4])

le_seg = preprocessing.LabelEncoder()
le_seg.fit([ 'Mass Customer','Affluent Customer','High Net Worth'])
X[:,6] = le_seg.transform(X[:,6])

le_car = preprocessing.LabelEncoder()
le_car.fit([ 'Yes','No'])
X[:,7] = le_car.transform(X[:,7])

# %%
X[0:20]
# Out:
# array([[2356, 2, 0, 1, 5, 58, 0, 0],
#        [2270, 1, 1, 2, 7, 50, 0, 0],
#        [1725, 0, 0, 0, 5, 80, 1, 1],
#        [1432, 2, 1, 0, 0, 70, 1, 1],
#        [444, 1, 0, 0, 5, 32, 2, 1],
#        [662, 1, 0, 2, 5, 41, 2, 1],
#        [2962, 0, 0, 0, 6, 26, 2, 0],
#        [640, 0, 1, 0, 1, 12, 1, 1],
#        [2298, 2, 1, 2, 6, 64, 2, 1],
#        [3195, 0, 0, 0, 5, 4, 2, 0],
#        [2492, 0, 1, 0, 5, 35, 1, 0],
#        [3465, 0, 0, 0, 5, 71, 1, 1],
#        [1748, 1, 1, 1, 5, 83, 2, 1],
#        [2309, 2, 1, 1, 5, 40, 0, 0],
#        [2989, 2, 1, 0, 3, 37, 1, 1],
#        [1784, 2, 0, 0, 5, 37, 2, 1],
#        [772, 2, 0, 0, 1, 12, 2, 0],
#        [2794, 0, 0, 0, 3, 41, 2, 1],
#        [551, 2, 0, 2, 2, 8, 1, 0],
#        [2770, 0, 1, 0, 5, 24, 1, 1]], dtype=object)

# %%
y = under_sample['R_label']
y[0:5]
y
# Out:
# 0       Others
# 1       Others
# 2         Best
# 3         Best
# 4         Best
#          ...
# 1611      Best
# 1612    Others
# 1613    Others
# 1614    Others
# 1615    Others
# Name: R_label, Length: 1616, dtype: object

# %%
#!pip install xgboost

# %% [markdown]
# ## Classification Models

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(  
    X, y, test_size = 0.2, random_state = 100)

# %%
X_train.shape,X_test.shape
# Out:
# ((1292, 8), (324, 8))

# %%
y_train.shape,y_test.shape
# Out:
# ((1292,), (324,))

# %%
from sklearn.ensemble import RandomForestClassifier

RF_clf = RandomForestClassifier(n_estimators=100, max_depth=2, max_features = 'sqrt',verbose = 1, bootstrap = False)
RF_clf.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.1s finished
# RandomForestClassifier(bootstrap=False, max_depth=2, max_features='sqrt',
#                        verbose=1)

# %%
test_score = RF_clf.score(X_test, y_test)
test_score
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# 0.49074074074074076

# %%
y_pred = RF_clf.predict(X_test)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished

# %%
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report

# %%
 print("Confusion Matrix: ", 
        confusion_matrix(y_test, y_pred)) 
      
print ("Accuracy : ", 
    accuracy_score(y_test,y_pred)*100) 
      
print("Report : ", 
    classification_report(y_test, y_pred))
# Out:
# Confusion Matrix:  [[ 60 102]
#  [ 63  99]]
# Accuracy :  49.074074074074076
# Report :                precision    recall  f1-score   support
#
#         Best       0.49      0.37      0.42       162
#       Others       0.49      0.61      0.55       162
#
#     accuracy                           0.49       324
#    macro avg       0.49      0.49      0.48       324
# weighted avg       0.49      0.49      0.48       324

# %%
from xgboost import XGBClassifier

# %%
xgb = XGBClassifier()

# %%
xgb.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=0, num_parallel_tree=1, random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
xgb.score(X_test, y_test)
# Out:
# 0.5462962962962963

# %%
y_predxgb = xgb.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report

# %%
 print("Confusion Matrix: ", 
        confusion_matrix(y_test, y_predxgb)) 
      
print ("Accuracy : ", 
    accuracy_score(y_test,y_predxgb)*100) 
      
print("Report : ", 
    classification_report(y_test, y_predxgb))
# Out:
# Confusion Matrix:  [[98 64]
#  [83 79]]
# Accuracy :  54.629629629629626
# Report :                precision    recall  f1-score   support
#
#         Best       0.54      0.60      0.57       162
#       Others       0.55      0.49      0.52       162
#
#     accuracy                           0.55       324
#    macro avg       0.55      0.55      0.54       324
# weighted avg       0.55      0.55      0.54       324

# %% [markdown]
# ## Predicting class labels for New Customers

# %%
df2 = pd.read_excel('C:\\Users\\Roshni Gaddam\\Downloads\\kpmg\\kdata\\newcustomers.xlsx')

# %% [markdown]
# Same preprocessing steps are applied to new customer data too.

# %%
df2['Age']=pd.cut(df2.Age,bins=[15,35,50,90],labels=['Young Adults','Middle Age','Older'])

# %% [markdown]
# ID,Age,gender,state,property_valuation,job_industry_category,past_3_years_bike_related_purchases,wealth_segment,owns_car,tenure are the features selected.

# %%
df2.head()
# Out:
#    ID           Age  gender state  property_valuation job_industry_category  \
# 0   1         Older  Female   QLD                   4                Health
# 1   2  Young Adults    Male   VIC                   7           Agriculture
# 2   3         Older    Male   QLD                   4    Financial Services
# 3   4    Middle Age  Female   NSW                   7         Manufacturing
# 4   5    Middle Age  Female   VIC                   8         Manufacturing
#
#    past_3_years_bike_related_purchases     wealth_segment owns_car  tenure
# 0                                   48  Affluent Customer      Yes      14
# 1                                   33  Affluent Customer       No      13
# 2                                   46     High Net Worth      Yes      13
# 3                                   39  Affluent Customer      Yes       9
# 4                                   81     High Net Worth       No       9

# %%
Xtest = df2[['ID','Age', 'gender', 'state','job_industry_category','past_3_years_bike_related_purchases','wealth_segment','owns_car']].values

# %%
Xtest.shape
# Out:
# (715, 8)

# %%
from sklearn import preprocessing

le_age = preprocessing.LabelEncoder()
le_age.fit(['Young Adults','Middle Age','Older'])
Xtest[:,1] = le_age.transform(Xtest[:,1]) 

le_gen = preprocessing.LabelEncoder()
le_gen.fit(['Female','Male'])
Xtest[:,2] = le_gen.transform(Xtest[:,2]) 


le_state = preprocessing.LabelEncoder()
le_state.fit([ 'NSW', 'VIC', 'QLD'])
Xtest[:,3] = le_state.transform(Xtest[:,3])

le_job = preprocessing.LabelEncoder()
le_job.fit([ 'Agriculture', 'Entertainment', 'Financial Services','Health','IT','Manufacturing','Property','Retail','Telecommunications'])
Xtest[:,4] = le_job.transform(Xtest[:,4])

le_seg = preprocessing.LabelEncoder()
le_seg.fit([ 'Mass Customer','Affluent Customer','High Net Worth'])
Xtest[:,6] = le_seg.transform(Xtest[:,6])

le_car = preprocessing.LabelEncoder()
le_car.fit([ 'Yes','No'])
Xtest[:,7] = le_car.transform(Xtest[:,7])

# %%
finalypred=xgb.predict(Xtest)

# %%
finalypred
# Out:
# array(['Best', 'Others', 'Best', 'Best', 'Best', 'Others', 'Best', 'Best',
#        'Others', 'Best', 'Others', 'Best', 'Others', 'Best', 'Others',
#        'Others', 'Best', 'Others', 'Best', 'Best', 'Others', 'Others',
#        'Best', 'Others', 'Best', 'Best', 'Best', 'Best', 'Others',
#        'Others', 'Others', 'Others', 'Others', 'Others', 'Others', 'Best',
#        'Best', 'Best', 'Others', 'Best', 'Best', 'Best', 'Others', 'Best',
#        'Best', 'Best', 'Others', 'Others', 'Best', 'Best', 'Others',
#        'Others', 'Best', 'Others', 'Others', 'Best', 'Best', 'Best',
#        'Others', 'Others', 'Best', 'Best', 'Best', 'Others', 'Others',
#        'Others', 'Others', 'Others', 'Others', 'Best', 'Others', 'Others',
#        'Others', 'Others', 'Others', 'Best', 'Best', 'Best', 'Others',
#        'Best', 'Others', 'Others', 'Others', 'Best', 'Best', 'Others',
#        'Best', 'Best', 'Best', 'Best', 'Best', 'Best', 'Best', 'Best',
#        'Best', 'Others', 'Best', 'Others', 'Best', 'Others', 'Best',
#        'Others', 'Others', 'Best', 'Best', 'Best', 'Best', 'Others',
#        'Best', 'Others', 'Best', 'Best', 'Best', 'Best', 'Best', 'Best',
#        'Best', 'Best', 'Best', 'Others', 'Others', 'Best', 'Best',
#        'Others', 'Best', 'Best', 'Others', 'Others', 'Best', 'Best',
#        'Others', 'Best', 'Best', 'Best', 'Best', 'Best', 'Best', 'Best',
#        'Best', 'Best', 'Best', 'Best', 'Best', 'Best', 'Best', 'Best',
#        'Best', 'Best', 'Others', 'Best', 'Best', 'Best', 'Best', 'Others',
#        'Others', 'Best', 'Others', 'Others', 'Best', 'Best', 'Best',
#        'Best', 'Best', 'Best', 'Best', 'Best', 'Others', 'Others', 'Best',
#        'Best', 'Others', 'Others', 'Best', 'Best', 'Best', 'Best', 'Best',
#        'Others', 'Best', 'Best', 'Best', 'Others', 'Best', 'Best', 'Best',
#        'Others', 'Others', 'Others', 'Others', 'Others', 'Best', 'Best',
#        'Others', 'Best', 'Best', 'Others', 'Others', 'Best', 'Others',
#        'Others', 'Others', 'Best', 'Others', 'Best', 'Best', 'Best',
#        'Others', 'Best', 'Best', 'Best', 'Others', 'Others', 'Best',
#        'Best', 'Others', 'Best', 'Others', 'Best', 'Best', 'Best',
#        'Others', 'Best', 'Others', 'Others', 'Others', 'Best', 'Best',
#        'Others', 'Best', 'Best', 'Best', 'Others', 'Others', 'Best',
#        'Best', 'Others', 'Others', 'Others', 'Best', 'Best', 'Best',
#        'Best', 'Best', 'Best', 'Best', 'Best', 'Best', 'Others', 'Others',
#        'Best', 'Best', 'Best', 'Others', 'Best', 'Best', 'Others',
#        'Others', 'Best', 'Best', 'Others', 'Others', 'Best', 'Best',
#        'Others', 'Others', 'Others', 'Others', 'Others', 'Others',
#        'Others', 'Others', 'Others', 'Others', 'Others', 'Best', 'Others',
#        'Others', 'Best', 'Others', 'Others', 'Others', 'Best', 'Best',
#        'Others', 'Others', 'Others', 'Others', 'Best', 'Others', 'Others',
#        'Others', 'Others', 'Best', 'Others', 'Others', 'Best', 'Others',
#        'Others', 'Others', 'Others', 'Others', 'Best', 'Others', 'Others',
#        'Best', 'Others', 'Best', 'Best', 'Best', 'Others', 'Best',
#        'Others', 'Others', 'Best', 'Best', 'Others', 'Best', 'Best',
#        'Best', 'Others', 'Best', 'Others', 'Best', 'Best', 'Others',
#        'Best', 'Others', 'Best', 'Best', 'Others', 'Best', 'Best', 'Best',
#        'Others', 'Others', 'Best', 'Best', 'Others', 'Best', 'Others',
#        'Others', 'Best', 'Others', 'Others', 'Best', 'Best', 'Best',
#        'Best', 'Best', 'Best', 'Best', 'Others', 'Best', 'Best', 'Best',
#        'Best', 'Best', 'Best', 'Best', 'Best', 'Best', 'Best', 'Best',
#        'Best', 'Best', 'Best', 'Others', 'Others', 'Others', 'Others',
#        'Others', 'Others', 'Others', 'Others', 'Others', 'Best', 'Best',
#        'Others', 'Best', 'Best', 'Best', 'Others', 'Others', 'Others',
#        'Best', 'Others', 'Best', 'Others', 'Best', 'Best', 'Others',
#        'Others', 'Best', 'Others', 'Others', 'Best', 'Best', 'Best',
#        'Best', 'Best', 'Others', 'Best', 'Best', 'Best', 'Others',
#        'Others', 'Others', 'Others', 'Best', 'Others', 'Best', 'Best',
#        'Best', 'Best', 'Best', 'Best', 'Best', 'Best', 'Best', 'Others',
#        'Best', 'Best', 'Best', 'Best', 'Best', 'Best', 'Best', 'Best',
#        'Best', 'Best', 'Best', 'Best', 'Best', 'Best', 'Best', 'Best',
#        'Best', 'Best', 'Best', 'Best', 'Best', 'Best', 'Best', 'Best',
#        'Best', 'Best', 'Others', 'Best', 'Others', 'Best', 'Others',
#        'Others', 'Others', 'Best', 'Best', 'Others', 'Others', 'Best',
#        'Others', 'Best', 'Others', 'Others', 'Best', 'Others', 'Others',
#        'Others', 'Others', 'Others', 'Others', 'Others', 'Others',
#        'Others', 'Best', 'Others', 'Best', 'Others', 'Others', 'Others',
#        'Best', 'Others', 'Best', 'Others', 'Others', 'Others', 'Others',
#        'Best', 'Best', 'Others', 'Others', 'Others', 'Others', 'Others',
#        'Others', 'Others', 'Others', 'Others', 'Others', 'Others',
#        'Others', 'Others', 'Others', 'Others', 'Others', 'Others',
#        'Others', 'Others', 'Best', 'Others', 'Best', 'Others', 'Others',
#        'Others', 'Others', 'Others', 'Others', 'Others', 'Others',
#        'Others', 'Best', 'Others', 'Others', 'Others', 'Others', 'Others',
#        'Others', 'Others', 'Best', 'Others', 'Others', 'Others', 'Others',
#        'Others', 'Others', 'Others', 'Others', 'Others', 'Others',
#        'Others', 'Others', 'Others', 'Others', 'Others', 'Others', 'Best',
#        'Others', 'Best', 'Best', 'Others', 'Others', 'Others', 'Best',
#        'Others', 'Others', 'Others', 'Others', 'Best', 'Others', 'Others',
#        'Others', 'Others', 'Others', 'Others', 'Others', 'Others',
#        'Others', 'Others', 'Best', 'Others', 'Best', 'Others', 'Others',
#        'Others', 'Others', 'Others', 'Others', 'Best', 'Best', 'Best',
#        'Best', 'Others', 'Others', 'Others', 'Others', 'Others', 'Others',
#        'Best', 'Best', 'Best', 'Best', 'Best', 'Best', 'Best', 'Others',
#        'Best', 'Best', 'Others', 'Others', 'Others', 'Best', 'Others',
#        'Best', 'Best', 'Best', 'Others', 'Best', 'Best', 'Others', 'Best',
#        'Best', 'Best', 'Best', 'Others', 'Best', 'Others', 'Others',
#        'Best', 'Best', 'Best', 'Others', 'Best', 'Best', 'Others',
#        'Others', 'Best', 'Best', 'Best', 'Others', 'Others', 'Best',
#        'Best', 'Best', 'Best', 'Best', 'Best', 'Best', 'Best', 'Best',
#        'Best', 'Best', 'Others', 'Others', 'Best', 'Others', 'Others',
#        'Others', 'Others', 'Others', 'Others', 'Best', 'Others', 'Others',
#        'Best', 'Best', 'Best', 'Best', 'Others', 'Best', 'Best', 'Others',
#        'Others', 'Others', 'Others', 'Others', 'Best', 'Others', 'Best',
#        'Best', 'Others', 'Others', 'Best', 'Best', 'Best', 'Others',
#        'Best', 'Others', 'Best', 'Best', 'Best', 'Others', 'Others',
#        'Others', 'Others', 'Best', 'Best', 'Others', 'Others', 'Best',
#        'Others', 'Best', 'Best', 'Best', 'Others', 'Others', 'Best',
#        'Best', 'Best', 'Others', 'Best', 'Others', 'Others', 'Best',
#        'Best', 'Best', 'Others', 'Others', 'Best', 'Others', 'Best',
#        'Best', 'Others', 'Others', 'Best', 'Others', 'Best', 'Others'],
#       dtype=object)

# %%
finalypred.shape
# Out:
# (715,)

# %%
final=pd.read_excel('C:\\Users\\Roshni Gaddam\\Downloads\\kpmg\\kdata\\newcustomerdetails.xlsx')
#final=df2

# %%
final['Age']=pd.cut(final.Age,bins=[15,35,50,90],labels=['Young Adults','Middle Age','Older'])

# %%
final.head()
# Out:
#    ID                 Name           Age  gender  \
# 0   1        Abigale Sives         Older  Female
# 1   2     Abner Fraschetti  Young Adults    Male
# 2   3     Adolpho Bellerby         Older    Male
# 3   4  Adria Van den Velde    Middle Age  Female
# 4   5   Adriane Richardson    Middle Age  Female
#
#    past_3_years_bike_related_purchases               job_title  \
# 0                                   48            VP Marketing
# 1                                   33         Staff Scientist
# 2                                   46                VP Sales
# 3                                   39  Nuclear Power Engineer
# 4                                   81         Data Coordiator
#
#   job_industry_category     wealth_segment owns_car  tenure  postcode state  \
# 0                Health  Affluent Customer      Yes      14      4207   QLD
# 1           Argiculture  Affluent Customer       No      13      3805   VIC
# 2    Financial Services     High Net Worth      Yes      13      4305   QLD
# 3         Manufacturing  Affluent Customer      Yes       9      2261   NSW
# 4         Manufacturing     High Net Worth       No       9      3070   VIC
#
#      country  property_valuation
# 0  Australia                   4
# 1  Australia                   7
# 2  Australia                   4
# 3  Australia                   7
# 4  Australia                   8

# %%
submission = pd.concat([pd.DataFrame(final), pd.DataFrame(finalypred)], axis = 'columns')

# %%
submission.rename(columns = {0:'Prediction'}, inplace = True)

# %%
submission['Prediction'][submission['Prediction']=="Best"]
# Out:
# 0      Best
# 2      Best
# 3      Best
# 4      Best
# 6      Best
#        ...
# 705    Best
# 707    Best
# 708    Best
# 711    Best
# 713    Best
# Name: Prediction, Length: 370, dtype: object

# %%
submission=submission[:][submission['Prediction']=="Best"]

# %% [markdown]
# Final submission is the data of High value target customers i.e; those whose class labels were predicted as "Best"

# %%
submission.to_excel(r'C:\Users\Roshni Gaddam\Downloads\kpmg\kdata\Target Customers.xlsx', index = False)
